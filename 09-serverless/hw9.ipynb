# %% [markdown]
# ## Homework
#
# In this homework, we'll deploy the Straight vs Curly Hair Type model we trained in the
# [previous homework](../08-deep-learning/homework.md).
#
# Download the model files from here:
#
# * https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data
# * https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx
#
# With wget:
#
# ```bash
# PREFIX="https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle"
# DATA_URL="${PREFIX}/hair_classifier_v1.onnx.data"
# MODEL_URL="${PREFIX}/hair_classifier_v1.onnx"
# wget ${DATA_URL}
# wget ${MODEL_URL}
# ```

# %% [markdown]
# ## Question 1
#
# To be able to use this model, we need to know the name of the input and output nodes.
#
# What's the name of the output:
#
# * **`output`**
# * sigmoid
# * softmax
# * prediction

# %%
# Download the ONNX model files
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx
# Out:
# --2025-12-03 07:46:34--  https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response...
# 302 Found
# ...

# %%
# Install the onnx library to inspect the model
# !pip install onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.1 MB ? eta -:--:--Downloading onnx-1.20.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 49.6 MB/s  0:00:006m0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 49.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.0 MB ? eta -:--:--Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 51.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 51.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [onnx]2/3 [onnx]ypes]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [onnx]
# ...

# %%
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/17.4 MB ? eta -:--:--Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from sympy->onnxruntime) (1.3.0)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 50.1 MB/s  0:00:006m0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 50.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [onnxruntime] [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [onnxruntime]
# ...

# %%
import onnxruntime as ort

# Load the ONNX model into an inference session
session = ort.InferenceSession("hair_classifier_v1.onnx", providers=["CPUExecutionProvider"])

# Get the output node names
outputs = session.get_outputs()
print("Output nodes:")
for output in outputs:
    print(output.name)
# Out:
# Output nodes:
# output

# %%
# ONNX models also define input and output nodes in their graph structure
import onnx

# Load the ONNX model
model = onnx.load("hair_classifier_v1.onnx")

# Print the output node names
print("Output nodes:")
for output in model.graph.output:
    print(output.name)
# Out:
# Output nodes:
# output

# %% [markdown]
# * ONNX models define input and output nodes in their graph structure
# * session.get_outputs() is used when the model is loaded into an ONNX Runtime inference session for making predictions.

# %% [markdown]
# ## Preparing the image
#
# You'll need some code for downloading and resizing images. You can use
# this code:
#
# ```python
# from io import BytesIO
# from urllib import request
#
# from PIL import Image
#
# def download_image(url):
#     with request.urlopen(url) as resp:
#         buffer = resp.read()
#     stream = BytesIO(buffer)
#     img = Image.open(stream)
#     return img
#
#
# def prepare_image(img, target_size):
#     if img.mode != 'RGB':
#         img = img.convert('RGB')
#     img = img.resize(target_size, Image.NEAREST)
#     return img
# ```
#
# For that, you'll need to have `pillow` installed:
#
# ```bash
# pip install pillow
# ```

# %% [markdown]
# ## Question 2: Target size
#
# Let's download and resize this image:
#
# https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg
#
# Based on the previous homework, what should be the target size for the image?
#
# * 64x64
# * 128x128
# * **`200x200`**
# * 256x256

# %%
#!pip install pillow

# %%
from io import BytesIO
from urllib import request

from PIL import Image

def download_image(url):
    with request.urlopen(url) as resp:
        buffer = resp.read()
    stream = BytesIO(buffer)
    img = Image.open(stream)
    return img


def prepare_image(img, target_size):
    if img.mode != 'RGB':
        img = img.convert('RGB')
    img = img.resize(target_size, Image.NEAREST)
    return img

# %%
from PIL import Image
import numpy as np

# Download the image
img = download_image("https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg")

# Resize to target size
img = prepare_image(img, (200, 200))

# %% [markdown]
# ## Question 3
#
# Now we need to turn the image into numpy array and pre-process it.
#
# > Tip: Check the previous homework. What was the pre-processing
# > we did there?
#
# After the pre-processing, what's the value in the first pixel, the R channel?
#
# * -10.73
# * **`-1.073`**
# * 1.073
# * 10.73

# %%
# Convert to numpy array
x = np.array(img)
print(x.shape)
# Out:
# (200, 200, 3)

# %%
#!pip install torchvision
# Out:
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...

# %%
# Pre-process the image
from torchvision import transforms

# Normalize the image using ImageNet mean and std
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# Convert the image to a tensor and normalize
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
])

# Apply the transformation
x_tensor = transform(x)

# Extract the first pixel's R channel (red) value
r_channel_value = x_tensor[0, 0, 0].item()
print(f"First pixel R channel value: {r_channel_value}")
# Out:
# First pixel R channel value: -1.0732940435409546

# %% [markdown]
# ## Question 4
#
# Now let's apply this model to this image. What's the output of the model?
#
# * **`0.09`**
# * 0.49
# * 0.69
# * 0.89

# %%
x_tensor.shape
# Out:
# torch.Size([3, 200, 200])

# %%
x_tensor.unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 200, 200])

# %%
# ONNX models expect a batch dimension. Transforms the shape to [1, 3, 200, 200]
x_input = x_tensor.unsqueeze(0).numpy()
x_input.shape
# Out:
# (1, 3, 200, 200)

# %%
# Pass the prepared input (x_input) to the model and retrieve the output
outputs = session.run(None, {"input": x_input})
print(outputs)
# Out:
# [array([[0.09156641]], dtype=float32)]

# %% [markdown]
# ## Prepare the lambda code
#
# Now you need to copy all the code into a separate python file. You will
# need to use this file for the next two questions.
#
# Tip: you can test this file locally with `ipython` or Jupyter Notebook
# by importing the file and invoking the function from this file.
#
#
# ## Docker
#
# For the next two questions, we'll use a Docker image that we already
# prepared. This is the Dockerfile that we used for creating the image:
#
# ```docker
# FROM public.ecr.aws/lambda/python:3.13
#
# COPY hair_classifier_empty.onnx.data .
# COPY hair_classifier_empty.onnx .
# ```
#
# Note that it uses Python 3.13.
#
# The docker image is published to [`agrigorev/model-2024-hairstyle:v3`](https://hub.docker.com/r/agrigorev/model-2024-hairstyle/tags).
#
# A few notes:
#
# * The image already contains a model and it's not the same model
#   as the one we used for questions 1-4.
#
# ## Question 5
#
# Download the base image `agrigorev/model-2025-hairstyle:v1`. You can do it with [`docker pull`](https://docs.docker.com/engine/reference/commandline/pull/).
#
# So what's the size of this base image?
#
# * 88 Mb
# * 208 Mb
# * **`608 Mb`**
# * 1208 Mb
#
# You can get this information when running `docker images` - it'll be in the "SIZE" column.

# %% [markdown]
# ## Question 6
#
# Now let's extend this docker image, install all the required libraries
# and add the code for lambda.
#
# You don't need to include the model in the image. It's already included.
# The name of the file with the model is `hair_classifier_empty.onnx` and it's
# in the current workdir in the image (see the Dockerfile above for the
# reference).
# The provided model requires the same preprocessing for images regarding target size and rescaling the value range than used in homework 8.
#
# Now run the container locally.
#
# Score this image: https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg
#
# What's the output from the model?
#
# * -1.0
# * **`-0.10`**
# * 0.10
# * 1.0

# %%
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx.data
# Out:
# --2025-12-03 14:49:15--  https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Procedure for Questions 5 and 6
#
# ### Step 1: Download the ONNX Model
# Download the ONNX model and its associated data file using the following commands:
# ```python
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx
# !wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx.data
# ```
#
# Run the hw9.py file:
#
# ```bash
# ./hw9.py
# ```
#
# ### Step 2: Set Up the Docker Environment
# Build the Docker image for the FastAPI application:
# ```bash
# docker build -t extended-hairstyle-model .
# ```
#
# ### Step 3: Run the Docker Container
# Start the container and expose the application on port 8000:
# ```bash
# docker run -p 8000:8000 extended-hairstyle-model
# ```
#
# ### Step 4: Test the `/predict` Endpoint
# Use the following `curl` command to test the `/predict` endpoint:
# ```bash
# curl -X POST -H "Content-Type: application/json" -d @json_data.json http://localhost:8000/predict
# ```
#
# ### Expected Result
# If everything is set up correctly, the output should look like this:
# ```bash
# {"prediction":[[-0.10220836102962494]]}
# ```
